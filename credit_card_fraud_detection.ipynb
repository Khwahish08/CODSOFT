# %% [markdown]
# <a href="https://colab.research.google.com/github/Khwahish08/CODSOFT/blob/main/credit_card_fraud_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')
credit_card_data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
(492/284808)*100
# Out:
# 0.17274795651807534

# %%
# 0--> Normal Transaction
# 1--> Fraud Transaction

# %%
valid = credit_card_data[credit_card_data.Class ==0]
fraud = credit_card_data[credit_card_data.Class ==1]

# %%
valid.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
valid.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
valid_sample = valid.sample(n = 492)

# %%
new_data = pd.concat([valid_sample, fraud], axis =0)

# %%
new_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 217873  141077.0 -0.633191  1.000092  1.280619 -0.355810  0.605984 -0.826327
# 157977  110711.0  2.068150  0.328697 -1.533604  0.610467  0.591131 -0.741163
# 107247   70355.0 -0.954163 -0.633802  1.284395 -0.569559  0.904669 -1.320205
# 23429    32750.0 -1.195212  1.203662  1.169083 -1.572416  0.097006 -0.427549
# 104794   69234.0 -1.089813  1.449431  0.847112 -0.031457 -0.414604 -1.002150
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 217873  1.222148 -0.239385 -0.482443  ... -0.218589 -0.546697 -0.348567
# 157977  0.140578 -0.344548  1.637843  ... -0.497195 -1.028309  0.350263
# 107247  0.640228 -0.548133  1.002000  ...  0.058361  0.708331  0.075008
# 23429   0.621869  0.140105  0.021263  ... -0.014855  0.100002 -0.061450
# 104794  0.410102  0.235094 -0.276902  ... -0.041851 -0.339990  0.057542
# ...          ...       ...       ...  ...       ...       ...       ...
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
#              V24       V25       V26       V27       V28  Amount  Class
# 217873  0.048993  0.701452 -0.339354  0.029584  0.058253   13.58      0
# 157977  0.472471 -0.268631  0.133659 -0.080274 -0.035223    1.79      0
# 107247  0.437161  0.038251 -0.525850 -0.290420 -0.195899   19.50      0
# 23429   0.055724 -0.292089  0.771503  0.342944  0.279058    3.69      0
# 104794  0.362588 -0.516490  0.050508 -0.189686  0.147260   11.90      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 279863 -0.294885  0.537503  0.788395  0.292680  0.147968  390.00      1
# 280143 -0.081049  0.521875  0.739467  0.389152  0.186637    0.76      1
# 280149  0.032070 -0.739695  0.471111  0.385107  0.194361   77.89      1
# 281144 -0.183659 -0.328168  0.606116  0.884876 -0.253700  245.00      1
# 281674 -0.450261  0.313267 -0.289617  0.002988 -0.015309   42.53      1
#
# [984 rows x 31 columns]

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96498.835366 -0.060509  0.182457 -0.037840 -0.083284 -0.000916
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.018924 -0.027182  0.059622  0.085462  ...  0.028389  0.019868
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.033702 -0.024891 -0.008226 -0.009584 -0.009775 -0.023026 -0.001474
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       76.030528
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
X = new_data.drop('Class', axis =1)
Y = new_data['Class']

# %%
X.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 217873  141077.0 -0.633191  1.000092  1.280619 -0.355810  0.605984 -0.826327
# 157977  110711.0  2.068150  0.328697 -1.533604  0.610467  0.591131 -0.741163
# 107247   70355.0 -0.954163 -0.633802  1.284395 -0.569559  0.904669 -1.320205
# 23429    32750.0 -1.195212  1.203662  1.169083 -1.572416  0.097006 -0.427549
# 104794   69234.0 -1.089813  1.449431  0.847112 -0.031457 -0.414604 -1.002150
#
#               V7        V8        V9  ...       V20       V21       V22  \
# 217873  1.222148 -0.239385 -0.482443  ...  0.039582 -0.218589 -0.546697
# 157977  0.140578 -0.344548  1.637843  ... -0.147830 -0.497195 -1.028309
# 107247  0.640228 -0.548133  1.002000  ...  0.149059  0.058361  0.708331
# 23429   0.621869  0.140105  0.021263  ...  0.248253 -0.014855  0.100002
# 104794  0.410102  0.235094 -0.276902  ... -0.115464 -0.041851 -0.339990
#
#              V23       V24       V25       V26       V27       V28  Amount
# 217873 -0.348567  0.048993  0.701452 -0.339354  0.029584  0.058253   13.58
# 157977  0.350263  0.472471 -0.268631  0.133659 -0.080274 -0.035223    1.79
# 107247  0.075008  0.437161  0.038251 -0.525850 -0.290420 -0.195899   19.50
# 23429  -0.061450  0.055724 -0.292089  0.771503  0.342944  0.279058    3.69
# 104794  0.057542  0.362588 -0.516490  0.050508 -0.189686  0.147260   11.90
#
# [5 rows x 30 columns]

# %%
Y.head()
# Out:
# 217873    0
# 157977    0
# 107247    0
# 23429     0
# 104794    0
# Name: Class, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y, random_state=3)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print("Training data's accuracy : ", training_data_accuracy)
# Out:
# Training data's accuracy :  0.9491740787801779

# %%
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print("Test data's accuracy score : ", test_data_accuracy)
# Out:
# Test data's accuracy score :  0.949238578680203

# %%
precision = precision_score(Y_test, X_test_prediction, average='weighted')
recall = recall_score(Y_test, X_test_prediction, average='weighted')
f1 = f1_score(Y_test, X_test_prediction, average='weighted')

# %%
print('Precision : ', precision)
# Out:
# Precision :  0.9499704826686604

# %%
print('Recall : ', recall)
# Out:
# Recall :  0.949238578680203

# %%
print('F1 score : ', f1)
# Out:
# F1 score :  0.9492124022046874
